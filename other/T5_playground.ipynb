# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))

# Function to remove stop words from a text
def remove_stop_words(text):
    word_tokens = word_tokenize(text)
    filtered_text = [word for word in word_tokens if word.casefold() not in stop_words]
    return " ".join(filtered_text)

def remove_punkt(text):
    word_tokens = word_tokenize(text)
    filtered_text = [word for word in word_tokens if word.isalnum()]
    return " ".join(filtered_text)
# Out:
# [nltk_data] Downloading package stopwords to /Users/dung/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/dung/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Rouge score

# %%
from rouge_score import rouge_scorer
import re

def clean_to_compare(text):
    text = remove_stop_words(text)
    text = remove_punkt(text)

    # remove actions
    text = re.sub(r'^(Convert|Make|Reframe|Adapt|Change|Modify|Transcribe|Translate|Transform|Rephrase|Rewrite|Revise|Edit|Alter|Amend|Adjust|Redraft|Reform|Rescript|Revamp|Vary|Convert|Turn|Transmute|Metamorphose|Metamorphize|Transfigure|Reconstruct|Edit|Add)', '', text)

    # noun
    text = re.sub(r'text|essay|paragraph|passage', '', text)
    text = text.strip()

    return text

scorer_for_rouge = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

def do_rouge_score(text1, text2):
    text1, text2 = list(map(clean_to_compare, [text1, text2]))
    print([text1, text2])
    scores = scorer_for_rouge.score(text1, text2)
    return scores

# Replace these with your sentences
sentences = [
    "Convert this into a sea shanty",
    "Make this a sea shanty",
    "Reframe this text to be a sea shanty",
    "Edit this passage for better flow and coherence.",
    "Transcribe this paragraph into a modern epigram."
]

for s in sentences[1:]:
    scores = do_rouge_score(sentences[0], s)
    print(scores)
# Out:
# ['sea shanty', 'sea shanty']
# {'rouge1': Score(precision=1.0, recall=1.0, fmeasure=1.0), 'rouge2': Score(precision=1.0, recall=1.0, fmeasure=1.0), 'rougeL': Score(precision=1.0, recall=1.0, fmeasure=1.0)}
# ['sea shanty', 'sea shanty']
# {'rouge1': Score(precision=1.0, recall=1.0, fmeasure=1.0), 'rouge2': Score(precision=1.0, recall=1.0, fmeasure=1.0), 'rougeL': Score(precision=1.0, recall=1.0, fmeasure=1.0)}
# ['sea shanty', 'better flow coherence']
# {'rouge1': Score(precision=0.0, recall=0.0, fmeasure=0.0), 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0), 'rougeL': Score(precision=0.0, recall=0.0, fmeasure=0.0)}
# ['sea shanty', 'modern epigram']
# {'rouge1': Score(precision=0.0, recall=0.0, fmeasure=0.0), 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0), 'rougeL': Score(precision=0.0, recall=0.0, fmeasure=0.0)}

# %% [markdown]
# T5 scoreing

# %%
import torch
from sentence_transformers import SentenceTransformer

t5base_model = None

def get_t5base_model():
    global t5base_model
    if t5base_model is None:
        t5base_model = SentenceTransformer('sentence-t5-base')
        if torch.cuda.is_available():
            t5base_model = t5base_model.to(torch.device("cuda"))
    return t5base_model

# Function to calculate sharpened cosine similarity
def sharpened_cosine_similarity(vec1, vec2, exponent=3):
    cosine_similarity = torch.nn.functional.cosine_similarity(vec1, vec2, dim=0)
    return cosine_similarity ** exponent

#provides similarity scores of a test_phrase against an array of phrases
def compare_phrases(test_phrase, phrases, model=None):
    if model is None:
        model = get_t5base_model()

    scores = []
    test_embedding = model.encode(test_phrase, convert_to_tensor=True, show_progress_bar=False)

    for phrase in phrases:
        compare_embedding = model.encode(phrase, convert_to_tensor=True, show_progress_bar=False)
        score = sharpened_cosine_similarity(test_embedding, compare_embedding).item()
        scores.append(score)

    return scores

# %%
import numpy as np

target = "Please improve the following text using the writing style of, maintaining the original meaning but altering the tone, diction, and stylistic elements to match the new style.Enhance the clarity, elegance, and impact of the following text by adopting the writing style of , ensuring the core message remains intact while transforming the tone, word choice, and stylistic features to align with the specified style."
target = "Refine the following passage by emulating the writing style of [insert desired style here], with a focus on enhancing its clarity, elegance, and overall impact. Preserve the essence and original meaning of the text, while meticulously adjusting its tone, vocabulary, and stylistic elements to resonate with the chosen style.Please improve the following text using the writing style of, maintaining the original meaning but altering the tone, diction, and stylistic elements to match the new style.Enhance the clarity, elegance, and impact of the following text by adopting the writing style of , ensuring the core message remains intact while transforming the tone, word choice, and stylistic features to align with the specified style."

targets = [
    "Please improve the following text using the writing style of, maintaining the original meaning",
    "Improve the following text using the writing style of, maintaining the original meaning",
    "Please improve the following text using the writing style of",
    "Please improve the following text using the writing style of, maintaining the original meaning but altering the tone, diction, and stylistic elements to match the new style.",
    "Please enhance the clarity, elegance, and impact of the following text by adopting the writing style of",
    "Please enhance the clarity, elegance, and impact of the following text by adopting the writing style of , ensuring the core message remains intact while transforming the tone, word choice, and stylistic features to align with the specified style.",
    "Please refine the following passage by emulating the writing style of, with a focus on enhancing its clarity, elegance, and overall impact.",
    "Please rreserve the essence and original meaning of the text, while meticulously adjusting its tone, vocabulary, and stylistic elements to resonate with the chosen style",
    "Please improve the following text using the writing style of, maintaining the original meaning but altering the tone, diction, and stylistic elements to match the new style",
    "Please enhance the clarity, elegance, and impact of the following text by adopting the writing style of , ensuring the core message remains intact while transforming the tone, word choice, and stylistic features to align with the specified style.",
]

texts = [
    "Reframe this text to be more engaging for a workshop.",
    "Make this text more suitable for a professional setting.",
    "Adapt this text to fit the format of a TED Talk script.",
    "Change the structure of this paragraph to be more engaging.",
    "Adjust the tone of this text to be more educational.",
    "Modify this text to sound lyrical as in a song.",
    "Transcribe this paragraph into a modern epigram.",
    "Rewrite this passage as a text message conversation.",
    "Paraphrase this passage to make it sound like a story.",
    "Transform this text to be in the style of a screenplay.",
    "Reconstruct this text as a piece of spoken word poetry.",
    "Revise the original text into a dialogue between two people.",
    "Rewrite this text as if it were spoken word poetry.",
    "Reframe this text for a professional audience.",
    "Reconstruct this text to be more contemplative.",
    "Revamp this text to sound like a marketing pitch.",
    "Add detail to this text to enhance the reader's understanding.",
    "Edit this passage for better flow and coherence.",
    "Revamp this text for a poetry reading.",
    "Rewrite this text to make it sound like an interview.",
]

# target = remove_stop_words(target)
# texts = [remove_stop_words(text) for text in texts]

for target in targets:
    scores = compare_phrases(target, texts)
    indices = np.argsort(scores)[::-1]

    print(f"\n=== Score: {np.mean(scores)}, Target: {target}\n")

    # for t, s in zip(texts, scores):
    #     print(f"{t} => {s:.4f}")

    for i in indices:
        print(f"{texts[i]} => {scores[i]:.4f}")
# Out:
# === Score: 0.6523946566241128, Target: Please improve the following text using the writing style of, maintaining the original meaning
#
# Edit this passage for better flow and coherence. => 0.7442
# Change the structure of this paragraph to be more engaging. => 0.7419
# Add detail to this text to enhance the reader's understanding. => 0.7122
# Make this text more suitable for a professional setting. => 0.7075
# Adjust the tone of this text to be more educational. => 0.7019
# Revamp this text for a poetry reading. => 0.6987
# Reconstruct this text to be more contemplative. => 0.6899
# Revise the original text into a dialogue between two people. => 0.6760
# Reframe this text to be more engaging for a workshop. => 0.6729
# Modify this text to sound lyrical as in a song. => 0.6603
# Transform this text to be in the style of a screenplay. => 0.6526
# Transcribe this paragraph into a modern epigram. => 0.6514
# Rewrite this text as if it were spoken word poetry. => 0.6497
# Reframe this text for a professional audience. => 0.6314
# Rewrite this text to make it sound like an interview. => 0.6259
# Rewrite this passage as a text message conversation. => 0.6195
# Adapt this text to fit the format of a TED Talk script. => 0.6178
# Reconstruct this text as a piece of spoken word poetry. => 0.6172
# Revamp this text to sound like a marketing pitch. => 0.6022
# Paraphrase this passage to make it sound like a story. => 0.5987
# Convert this into a sea shanty. => 0.4283
#
# === Score: 0.6497276212487902, Target: Improve the following text using the writing style of, maintaining the original meaning
#
# Change the structure of this paragraph to be more engaging. => 0.7135
# Add detail to this text to enhance the reader's understanding. => 0.7110
# Edit this passage for better flow and coherence. => 0.7028
# Make this text more suitable for a professional setting. => 0.6899
# Adjust the tone of this text to be more educational. => 0.6891
# Transform this text to be in the style of a screenplay. => 0.6842
# Revise the original text into a dialogue between two people. => 0.6838
# Revamp this text for a poetry reading. => 0.6792
# Reconstruct this text to be more contemplative. => 0.6773
# Modify this text to sound lyrical as in a song. => 0.6660
# Reframe this text to be more engaging for a workshop. => 0.6658
# Rewrite this text as if it were spoken word poetry. => 0.6651
# Transcribe this paragraph into a modern epigram. => 0.6611
# Reconstruct this text as a piece of spoken word poetry. => 0.6353
# Reframe this text for a professional audience. => 0.6269
# Adapt this text to fit the format of a TED Talk script. => 0.6254
# Rewrite this passage as a text message conversation. => 0.6227
# Rewrite this text to make it sound like an interview. => 0.6164
# Revamp this text to sound like a marketing pitch. => 0.6023
# Paraphrase this passage to make it sound like a story. => 0.5990
# Convert this into a sea shanty. => 0.4276
#
# === Score: 0.6379530642713819, Target: Please improve the following text using the writing style of
#
# Change the structure of this paragraph to be more engaging. => 0.7471
# Edit this passage for better flow and coherence. => 0.7375
# Make this text more suitable for a professional setting. => 0.7016
# Adjust the tone of this text to be more educational. => 0.6839
# Add detail to this text to enhance the reader's understanding. => 0.6815
# Revamp this text for a poetry reading. => 0.6708
# Reframe this text to be more engaging for a workshop. => 0.6584
# Reconstruct this text to be more contemplative. => 0.6517
# Rewrite this text as if it were spoken word poetry. => 0.6442
# Transform this text to be in the style of a screenplay. => 0.6377
# Revise the original text into a dialogue between two people. => 0.6344
# Rewrite this text to make it sound like an interview. => 0.6334
# Transcribe this paragraph into a modern epigram. => 0.6315
# Rewrite this passage as a text message conversation. => 0.6303
# Modify this text to sound lyrical as in a song. => 0.6194
# Reframe this text for a professional audience. => 0.6165
# Adapt this text to fit the format of a TED Talk script. => 0.6131
# Reconstruct this text as a piece of spoken word poetry. => 0.6008
# Paraphrase this passage to make it sound like a story. => 0.5983
# Revamp this text to sound like a marketing pitch. => 0.5881
# Convert this into a sea shanty. => 0.4170
#
# === Score: 0.6516224529061999, Target: Please improve the following text using the writing style of, maintaining the original meaning but altering the tone, diction, and stylistic elements to match the new style.
#
# Adjust the tone of this text to be more educational. => 0.7612
# Change the structure of this paragraph to be more engaging. => 0.7231
# Edit this passage for better flow and coherence. => 0.7220
# Make this text more suitable for a professional setting. => 0.7140
# Revise the original text into a dialogue between two people. => 0.6934
# Revamp this text for a poetry reading. => 0.6909
# Add detail to this text to enhance the reader's understanding. => 0.6815
# Reframe this text to be more engaging for a workshop. => 0.6682
# Reconstruct this text to be more contemplative. => 0.6667
# Modify this text to sound lyrical as in a song. => 0.6654
# Transform this text to be in the style of a screenplay. => 0.6641
# Rewrite this text as if it were spoken word poetry. => 0.6534
# Transcribe this paragraph into a modern epigram. => 0.6483
# Rewrite this text to make it sound like an interview. => 0.6365
# Reframe this text for a professional audience. => 0.6279
# Adapt this text to fit the format of a TED Talk script. => 0.6149
# Rewrite this passage as a text message conversation. => 0.6098
# Revamp this text to sound like a marketing pitch. => 0.6097
# Reconstruct this text as a piece of spoken word poetry. => 0.6094
# Paraphrase this passage to make it sound like a story. => 0.5789
# Convert this into a sea shanty. => 0.4447
#
# === Score: 0.6277132147834414, Target: Please enhance the clarity, elegance, and impact of the following text by adopting the writing style of
#
# Add detail to this text to enhance the reader's understanding. => 0.7400
# Make this text more suitable for a professional setting. => 0.7285
# Adjust the tone of this text to be more educational. => 0.7040
# Edit this passage for better flow and coherence. => 0.6876
# Change the structure of this paragraph to be more engaging. => 0.6830
# Reconstruct this text to be more contemplative. => 0.6557
# Reframe this text to be more engaging for a workshop. => 0.6512
# Revamp this text for a poetry reading. => 0.6485
# Reframe this text for a professional audience. => 0.6396
# Transcribe this paragraph into a modern epigram. => 0.6391
# Transform this text to be in the style of a screenplay. => 0.6353
# Rewrite this text as if it were spoken word poetry. => 0.6256
# Revise the original text into a dialogue between two people. => 0.6185
# Reconstruct this text as a piece of spoken word poetry. => 0.6070
# Modify this text to sound lyrical as in a song. => 0.6063
# Adapt this text to fit the format of a TED Talk script. => 0.6005
# Rewrite this passage as a text message conversation. => 0.5887
# Rewrite this text to make it sound like an interview. => 0.5885
# Revamp this text to sound like a marketing pitch. => 0.5770
# Paraphrase this passage to make it sound like a story. => 0.5580
# Convert this into a sea shanty. => 0.3995
#
# === Score: 0.622100830078125, Target: Please enhance the clarity, elegance, and impact of the following text by adopting the writing style of , ensuring the core message remains intact while transforming the tone, word choice, and stylistic features to align with the specified style.
#
# Make this text more suitable for a professional setting. => 0.7210
# Adjust the tone of this text to be more educational. => 0.7165
# Add detail to this text to enhance the reader's understanding. => 0.7161
# Change the structure of this paragraph to be more engaging. => 0.6705
# Edit this passage for better flow and coherence. => 0.6632
# Transcribe this paragraph into a modern epigram. => 0.6454
# Reframe this text for a professional audience. => 0.6454
# Reframe this text to be more engaging for a workshop. => 0.6377
# Reconstruct this text to be more contemplative. => 0.6340
# Transform this text to be in the style of a screenplay. => 0.6307
# Revamp this text for a poetry reading. => 0.6228
# Revise the original text into a dialogue between two people. => 0.6183
# Modify this text to sound lyrical as in a song. => 0.6145
# Rewrite this text as if it were spoken word poetry. => 0.6119
# Adapt this text to fit the format of a TED Talk script. => 0.6025
# Revamp this text to sound like a marketing pitch. => 0.5996
# Reconstruct this text as a piece of spoken word poetry. => 0.5953
# Rewrite this passage as a text message conversation. => 0.5953
# Rewrite this text to make it sound like an interview. => 0.5842
# Paraphrase this passage to make it sound like a story. => 0.5412
# Convert this into a sea shanty. => 0.3979
#
# === Score: 0.6432646158195677, Target: Please refine the following passage by emulating the writing style of, with a focus on enhancing its clarity, elegance, and overall impact.
#
# Edit this passage for better flow and coherence. => 0.7678
# Change the structure of this paragraph to be more engaging. => 0.7470
# Add detail to this text to enhance the reader's understanding. => 0.7044
# Transcribe this paragraph into a modern epigram. => 0.6849
# Paraphrase this passage to make it sound like a story. => 0.6689
# Adjust the tone of this text to be more educational. => 0.6640
# Make this text more suitable for a professional setting. => 0.6600
# Reconstruct this text to be more contemplative. => 0.6579
# Rewrite this text as if it were spoken word poetry. => 0.6561
# Revamp this text for a poetry reading. => 0.6549
# Reframe this text to be more engaging for a workshop. => 0.6465
# Transform this text to be in the style of a screenplay. => 0.6440
# Reconstruct this text as a piece of spoken word poetry. => 0.6364
# Reframe this text for a professional audience. => 0.6362
# Rewrite this passage as a text message conversation. => 0.6311
# Modify this text to sound lyrical as in a song. => 0.6248
# Rewrite this text to make it sound like an interview. => 0.6235
# Revise the original text into a dialogue between two people. => 0.6185
# Adapt this text to fit the format of a TED Talk script. => 0.5903
# Revamp this text to sound like a marketing pitch. => 0.5845
# Convert this into a sea shanty. => 0.4066
#
# === Score: 0.5616498206342969, Target: Please rreserve the essence and original meaning of the text, while meticulously adjusting its tone, vocabulary, and stylistic elements to resonate with the chosen style
#
# Adjust the tone of this text to be more educational. => 0.6682
# Revamp this text for a poetry reading. => 0.6286
# Make this text more suitable for a professional setting. => 0.6226
# Revise the original text into a dialogue between two people. => 0.6221
# Add detail to this text to enhance the reader's understanding. => 0.6089
# Reconstruct this text to be more contemplative. => 0.6078
# Reframe this text to be more engaging for a workshop. => 0.5843
# Reframe this text for a professional audience. => 0.5841
# Edit this passage for better flow and coherence. => 0.5814
# Transform this text to be in the style of a screenplay. => 0.5711
# Modify this text to sound lyrical as in a song. => 0.5633
# Rewrite this text as if it were spoken word poetry. => 0.5625
# Reconstruct this text as a piece of spoken word poetry. => 0.5608
# Adapt this text to fit the format of a TED Talk script. => 0.5486
# Change the structure of this paragraph to be more engaging. => 0.5347
# Transcribe this paragraph into a modern epigram. => 0.5339
# Rewrite this text to make it sound like an interview. => 0.5228
# Revamp this text to sound like a marketing pitch. => 0.5171
# Rewrite this passage as a text message conversation. => 0.5037
# Paraphrase this passage to make it sound like a story. => 0.4644
# Convert this into a sea shanty. => 0.4035
#
# === Score: 0.6515963347185225, Target: Please improve the following text using the writing style of, maintaining the original meaning but altering the tone, diction, and stylistic elements to match the new style
#
# Adjust the tone of this text to be more educational. => 0.7621
# Change the structure of this paragraph to be more engaging. => 0.7232
# Edit this passage for better flow and coherence. => 0.7231
# Make this text more suitable for a professional setting. => 0.7130
# Revamp this text for a poetry reading. => 0.6936
# Revise the original text into a dialogue between two people. => 0.6922
# Add detail to this text to enhance the reader's understanding. => 0.6807
# Reframe this text to be more engaging for a workshop. => 0.6702
# Transform this text to be in the style of a screenplay. => 0.6662
# Modify this text to sound lyrical as in a song. => 0.6661
# Reconstruct this text to be more contemplative. => 0.6661
# Rewrite this text as if it were spoken word poetry. => 0.6545
# Transcribe this paragraph into a modern epigram. => 0.6479
# Rewrite this text to make it sound like an interview. => 0.6313
# Reframe this text for a professional audience. => 0.6261
# Adapt this text to fit the format of a TED Talk script. => 0.6152
# Reconstruct this text as a piece of spoken word poetry. => 0.6100
# Revamp this text to sound like a marketing pitch. => 0.6095
# Rewrite this passage as a text message conversation. => 0.6093
# Paraphrase this passage to make it sound like a story. => 0.5798
# Convert this into a sea shanty. => 0.4433
#
# === Score: 0.622100830078125, Target: Please enhance the clarity, elegance, and impact of the following text by adopting the writing style of , ensuring the core message remains intact while transforming the tone, word choice, and stylistic features to align with the specified style.
#
# Make this text more suitable for a professional setting. => 0.7210
# Adjust the tone of this text to be more educational. => 0.7165
# Add detail to this text to enhance the reader's understanding. => 0.7161
# Change the structure of this paragraph to be more engaging. => 0.6705
# Edit this passage for better flow and coherence. => 0.6632
# Transcribe this paragraph into a modern epigram. => 0.6454
# Reframe this text for a professional audience. => 0.6454
# Reframe this text to be more engaging for a workshop. => 0.6377
# Reconstruct this text to be more contemplative. => 0.6340
# Transform this text to be in the style of a screenplay. => 0.6307
# Revamp this text for a poetry reading. => 0.6228
# Revise the original text into a dialogue between two people. => 0.6183
# Modify this text to sound lyrical as in a song. => 0.6145
# Rewrite this text as if it were spoken word poetry. => 0.6119
# Adapt this text to fit the format of a TED Talk script. => 0.6025
# Revamp this text to sound like a marketing pitch. => 0.5996
# Reconstruct this text as a piece of spoken word poetry. => 0.5953
# Rewrite this passage as a text message conversation. => 0.5953
# Rewrite this text to make it sound like an interview. => 0.5842
# Paraphrase this passage to make it sound like a story. => 0.5412
# Convert this into a sea shanty. => 0.3979

# %% [markdown]
# # model playground
